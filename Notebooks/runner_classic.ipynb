# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step train_pim --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Train PIM model                                                                            #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# Backbone Initialized...
# ::: Number of PIM Model Parameters:  486
# ::: Best Model Save Path:  ./save/CH0/dgru/train_pim/PIM_S_0_M_DGRU_H_8_F_50_P_486.pt
# ::: Log-History     Path:  ./log/CH0/dgru/train_pim/history/PIM_S_0_M_DGRU_H_8_F_50_P_486.csv
# ::: Log-Best        Path:  ./log/CH0/dgru/train_pim/best/PIM_S_0_M_DGRU_H_8_F_50_P_486.csv
# ...

# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step run_pim --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Run PIM model to get predictions                                                           #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# Backbone Initialized...
# ::: Number of PIM Model Parameters:  486
# ::: Number of Network Parameters:  486
# /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/instancenorm.py:88: UserWarning: input's size at dim=0 does not match num_features. You can silence this warning by not passing in num_features, which is not used because affine=False
#   warnings.warn(f"input's size at dim={feature_dim} does not match num_features. "
# ...

# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step train_pim --PIM_backbone gru --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Train PIM model                                                                            #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# /opt/anaconda3/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Backbone Initialized...
# ::: Number of PIM Model Parameters:  306
# ::: Best Model Save Path:  ./save/CH0/gru/train_pim/PIM_S_0_M_GRU_H_8_F_50_P_306.pt
# ::: Log-History     Path:  ./log/CH0/gru/train_pim/history/PIM_S_0_M_GRU_H_8_F_50_P_306.csv
# ...

# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step run_pim --PIM_backbone gru --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Run PIM model to get predictions                                                           #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# Backbone Initialized...
# ::: Number of PIM Model Parameters:  306
# ::: Number of Network Parameters:  306
# /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/instancenorm.py:88: UserWarning: input's size at dim=0 does not match num_features. You can silence this warning by not passing in num_features, which is not used because affine=False
#   warnings.warn(f"input's size at dim={feature_dim} does not match num_features. "
# ...

# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step train_pim --PIM_backbone lstm --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Train PIM model                                                                            #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# /opt/anaconda3/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Backbone Initialized...
# ::: Number of PIM Model Parameters:  402
# ::: Best Model Save Path:  ./save/CH0/lstm/train_pim/PIM_S_0_M_LSTM_H_8_F_50_P_402.pt
# ::: Log-History     Path:  ./log/CH0/lstm/train_pim/history/PIM_S_0_M_LSTM_H_8_F_50_P_402.csv
# ...

# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step run_pim --PIM_backbone lstm --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Run PIM model to get predictions                                                           #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# Backbone Initialized...
# ::: Number of PIM Model Parameters:  402
# ::: Number of Network Parameters:  402
# /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/instancenorm.py:88: UserWarning: input's size at dim=0 does not match num_features. You can silence this warning by not passing in num_features, which is not used because affine=False
#   warnings.warn(f"input's size at dim={feature_dim} does not match num_features. "
# ...

# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step train_pim --PIM_backbone qgru_amp1 --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Train PIM model                                                                            #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# /opt/anaconda3/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# ::: Number of PIM Model Parameters:  354
# ::: Best Model Save Path:  ./save/CH0/qgru_amp1/train_pim/PIM_S_0_M_QGRU_AMP1_H_8_F_50_P_354.pt
# ::: Log-History     Path:  ./log/CH0/qgru_amp1/train_pim/history/PIM_S_0_M_QGRU_AMP1_H_8_F_50_P_354.csv
# ...

# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step run_pim --PIM_backbone qgru_amp1 --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Run PIM model to get predictions                                                           #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# ::: Number of PIM Model Parameters:  354
# ::: Number of Network Parameters:  354
# /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/instancenorm.py:88: UserWarning: input's size at dim=0 does not match num_features. You can silence this warning by not passing in num_features, which is not used because affine=False
#   warnings.warn(f"input's size at dim={feature_dim} does not match num_features. "
# PIM outputs saved to the ./pim_out folder.

# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step train_pim --PIM_backbone qgru --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Train PIM model                                                                            #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# /opt/anaconda3/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# ::: Number of PIM Model Parameters:  354
# ::: Best Model Save Path:  ./save/CH0/qgru/train_pim/PIM_S_0_M_QGRU_H_8_F_50_P_354.pt
# ::: Log-History     Path:  ./log/CH0/qgru/train_pim/history/PIM_S_0_M_QGRU_H_8_F_50_P_354.csv
# ...

# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step run_pim --PIM_backbone qgru --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Run PIM model to get predictions                                                           #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# ::: Number of PIM Model Parameters:  354
# ::: Number of Network Parameters:  354
# /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/instancenorm.py:88: UserWarning: input's size at dim=0 does not match num_features. You can silence this warning by not passing in num_features, which is not used because affine=False
#   warnings.warn(f"input's size at dim={feature_dim} does not match num_features. "
# PIM outputs saved to the ./pim_out folder.

# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step train_pim --PIM_backbone rvtdcnn --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Train PIM model                                                                            #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# /opt/anaconda3/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# ::: Number of PIM Model Parameters:  344
# ::: Best Model Save Path:  ./save/CH0/rvtdcnn/train_pim/PIM_S_0_M_RVTDCNN_H_8_F_50_P_344.pt
# ::: Log-History     Path:  ./log/CH0/rvtdcnn/train_pim/history/PIM_S_0_M_RVTDCNN_H_8_F_50_P_344.csv
# ...

# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step run_pim --PIM_backbone rvtdcnn --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Run PIM model to get predictions                                                           #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# ::: Number of PIM Model Parameters:  344
# ::: Number of Network Parameters:  344
# PIM outputs saved to the ./pim_out folder.

# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step train_pim --PIM_backbone vdlstm --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Train PIM model                                                                            #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# /opt/anaconda3/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Backbone Initialized...
# ::: Number of PIM Model Parameters:  538
# ::: Best Model Save Path:  ./save/CH0/vdlstm/train_pim/PIM_S_0_M_VDLSTM_H_8_F_50_P_538.pt
# ::: Log-History     Path:  ./log/CH0/vdlstm/train_pim/history/PIM_S_0_M_VDLSTM_H_8_F_50_P_538.csv
# ...

# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step run_pim --PIM_backbone vdlstm --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Run PIM model to get predictions                                                           #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# Backbone Initialized...
# ::: Number of PIM Model Parameters:  538
# ::: Number of Network Parameters:  538
# /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/instancenorm.py:88: UserWarning: input's size at dim=0 does not match num_features. You can silence this warning by not passing in num_features, which is not used because affine=False
#   warnings.warn(f"input's size at dim={feature_dim} does not match num_features. "
# ...

# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step train_pim --PIM_backbone gmp --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Train PIM model                                                                            #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# /opt/anaconda3/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Backbone Initialized...
# ::: Number of PIM Model Parameters:  495
# ::: Best Model Save Path:  ./save/CH0/gmp/train_pim/PIM_S_0_M_GMP_H_8_F_50_P_495.pt
# ::: Log-History     Path:  ./log/CH0/gmp/train_pim/history/PIM_S_0_M_GMP_H_8_F_50_P_495.csv
# ...

# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step run_pim --PIM_backbone gmp --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Run PIM model to get predictions                                                           #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# Backbone Initialized...
# ::: Number of PIM Model Parameters:  495
# ::: Number of Network Parameters:  495
# PIM outputs saved to the ./pim_out folder.

# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step train_pim --PIM_backbone dgru_abs_only --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Train PIM model                                                                            #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# /opt/anaconda3/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Backbone Initialized...
# ::: Number of PIM Model Parameters:  382
# ::: Best Model Save Path:  ./save/CH0/dgru_abs_only/train_pim/PIM_S_0_M_DGRU_ABS_ONLY_H_8_F_50_P_382.pt
# ...

# %%
run ../main.py --dataset_path ../../../Data/FOR_COOPERATION/Prepared/1TR_C20Nc1CD_E20Ne1CD_20250117_5m --dataset_name CH0 --step run_pim --PIM_backbone dgru_abs_only --accelerator cpu
# Out:
# ::: Are Deterministic Algorithms Enabled:  False
# --------------------------------------------------------------------
# ####################################################################################################
# # Step: Run PIM model to get predictions                                                           #
# ####################################################################################################
# ::: Available GPUs: None
# --------------------------------------------------------------------
# Backbone Initialized...
# ::: Number of PIM Model Parameters:  382
# ::: Number of Network Parameters:  382
# /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/instancenorm.py:88: UserWarning: input's size at dim=0 does not match num_features. You can silence this warning by not passing in num_features, which is not used because affine=False
#   warnings.warn(f"input's size at dim={feature_dim} does not match num_features. "
# ...
